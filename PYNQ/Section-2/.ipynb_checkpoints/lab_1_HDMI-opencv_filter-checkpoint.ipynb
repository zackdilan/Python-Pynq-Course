# %% [markdown]
# # Open CV filter - LAB
#
# In this lab section, you are going to work with HDMI iumages and apply an open cv filter
# For the sake of Simplicity we will use a Image smoothing or blurring  filter.
#
# Youy can find more details about the  smoothing filter from here : https://docs.opencv.org/4.5.2/d4/d13/tutorial_py_filtering.html

# %% [markdown]
# ## Load the Overlay

# %%
from pynq.overlays.base import BaseOverlay
from pynq.lib.video import *

base = BaseOverlay("base.bit")
hdmi_in = base.video.hdmi_in
hdmi_out = base.video.hdmi_out

# %% [markdown]
# ### Step 2: Initialize HDMI I/O

# %%
hdmi_in.configure(PIXEL_RGB)
hdmi_out.configure(hdmi_in.mode, PIXEL_RGB)

hdmi_in.start()
hdmi_out.start()

# %% [markdown]
# ### Step 3: Show input frame using IPython Image

# %%
import PIL.Image
frame = hdmi_in.readframe()
img = PIL.Image.fromarray(frame)
img
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0xB3ADF470>

# %% [markdown]
# ### Do the filtering and show the blurred image on HDMI out
#  you can use cv2.blur() for image smoothing

# %%
import cv2
import numpy as np

result = np.ndarray(shape=(hdmi_in.mode.height, 
                           hdmi_in.mode.width), dtype=np.uint8)

# blur the image
in_frame = hdmi_in.readframe()
out_frame = hdmi_out.newframe()
cv2.blur(in_frame,(10,10),dst=out_frame)
hdmi_out.writeframe(out_frame)

# %% [markdown]
# ### show the image within the notebook

# %%
blur_img = PIL.Image.fromarray(out_frame)
blur_img
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0xAD86FC30>
